# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import linregress
import seaborn as sns
import numpy as np
from scipy.stats import sem
import pandas as pd
from sqlalchemy import create_engine

# %%
#This is the full data frame with some extra columns removed
health_df = pd.read_csv("Resources/Provisional_COVID-19_Deaths_by_Sex_and_Age.csv")
health_df = health_df.drop(columns = ["Data As Of", "Start Date", "End Date", "Footnote"])
health_df.head()
# Out:
#       Group  Year  Month          State        Sex     Age Group  \
# 0  By Total   NaN    NaN  United States  All Sexes      All Ages
# 1  By Total   NaN    NaN  United States  All Sexes  Under 1 year
# 2  By Total   NaN    NaN  United States  All Sexes    0-17 years
# 3  By Total   NaN    NaN  United States  All Sexes     1-4 years
# 4  By Total   NaN    NaN  United States  All Sexes    5-14 years
#
#    COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# 0         983409.0     7638997.0          865864.0
# 1            248.0       42516.0             524.0
# 2            962.0       75444.0            1520.0
# 3            121.0        7931.0             306.0
# 4            303.0       12627.0             439.0
#
#    Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# 0                       509298.0           10810.0
# 1                           31.0              28.0
# 2                          258.0             206.0
# 3                           30.0              70.0
# 4                           98.0              84.0
#
#    Pneumonia, Influenza, or COVID-19 Deaths
# 0                                 1349186.0
# 1                                     768.0
# 2                                    2427.0
# 3                                     467.0
# 4                                     727.0

# %%
#I have removed some random age groups
age_adjusted_df = health_df.loc[(health_df["Age Group"] != "40-49 years") &
                                (health_df["Age Group"] != "30-39 years") &
                                (health_df["Age Group"] != "18-29 years") &
                                (health_df["Age Group"] != "0-17 years") &
                                (health_df["Age Group"] != "50-64 years"), :]

# %%
#This data frame shows deaths by year, regardless of Month.
#You can pick 2020, 2021, or 2022
#This data frame can be sorted by State, Sex, and Age Group
#State: You can choose any of the 50 states, Puerto Rico, or the United States as a whole
#Sex: Male, Female, All Sexes
#Age Group:
    #All ages
    #Under 1 year
    #1-4 years old
    #5-14 years old
    #15-24 years old
    #25-34 years old
    #35-44 years old
    #45-54 years old
    #55-64 years old
    #65-74 years old
    #75-84 years old
    #85 years and over
year_df = age_adjusted_df.loc[health_df["Group"] == "By Year", :]
year_df = year_df.drop(columns = ["Month", "Group"])
year_df = year_df.replace("New York City", "New York")
year_df.head()
# Out:
#         Year          State        Sex     Age Group  COVID-19 Deaths  \
# 2754  2020.0  United States  All Sexes      All Ages         385480.0
# 2755  2020.0  United States  All Sexes  Under 1 year             52.0
# 2757  2020.0  United States  All Sexes     1-4 years             25.0
# 2758  2020.0  United States  All Sexes    5-14 years             69.0
# 2759  2020.0  United States  All Sexes   15-24 years            616.0
#
#       Total Deaths  Pneumonia Deaths  Pneumonia and COVID-19 Deaths  \
# 2754     3389057.0          351879.0                       179994.0
# 2755       19608.0             241.0                            9.0
# 2757        3527.0             132.0                            4.0
# 2758        5639.0             172.0                           12.0
# 2759       35961.0             773.0                          223.0
#
#       Influenza Deaths  Pneumonia, Influenza, or COVID-19 Deaths
# 2754            8785.0                                  564999.0
# 2755              21.0                                     305.0
# 2757              61.0                                     214.0
# 2758              76.0                                     305.0
# 2759              80.0                                    1241.0

# %%
year_states_df = year_df.loc[((health_df["Year"] == 2021.0) & (health_df["State"] != "United States")), :]
year_states_df = year_states_df.drop(columns = ["Sex", "Age Group", "Total Deaths", "Pneumonia Deaths", 
                                                "Pneumonia and COVID-19 Deaths", "Influenza Deaths", 
                                                "Pneumonia, Influenza, or COVID-19 Deaths"])
year_states_df = year_states_df.groupby(["State", "Year"])["COVID-19 Deaths"].sum()
all_states_df = pd.DataFrame(year_states_df)
#all_states_df.rename(columns="State: state")
#all_states_df["Year"] = all_states_df["Year"].astype(str)
all_states_df
# Out:
#                              COVID-19 Deaths
# State                Year
# Alabama              2021.0          38808.0
# Alaska               2021.0           3320.0
# Arizona              2021.0          56120.0
# Arkansas             2021.0          21302.0
# California           2021.0         192778.0
# Colorado             2021.0          24696.0
# Connecticut          2021.0          12568.0
# Delaware             2021.0           5029.0
# District of Columbia 2021.0           2793.0
# Florida              2021.0         155159.0
# Georgia              2021.0          69006.0
# Hawaii               2021.0           2904.0
# Idaho                2021.0          11111.0
# Illinois             2021.0          47066.0
# Indiana              2021.0          40128.0
# Iowa                 2021.0          14066.0
# Kansas               2021.0          15168.0
# Kentucky             2021.0          34667.0
# Louisiana            2021.0          27548.0
# Maine                2021.0           5694.0
# Maryland             2021.0          24330.0
# Massachusetts        2021.0          22252.0
# Michigan             2021.0          59548.0
# Minnesota            2021.0          20633.0
# Mississippi          2021.0          23596.0
# Missouri             2021.0          35654.0
# Montana              2021.0           7231.0
# Nebraska             2021.0           7736.0
# Nevada               2021.0          22547.0
# New Hampshire        2021.0           4770.0
# New Jersey           2021.0          38255.0
# New Mexico           2021.0          14614.0
# New York             2021.0          95196.0
# North Carolina       2021.0          60688.0
# North Dakota         2021.0           3731.0
# Ohio                 2021.0          81886.0
# Oklahoma             2021.0          31182.0
# Oregon               2021.0          16614.0
# Pennsylvania         2021.0          82006.0
# Puerto Rico          2021.0           6538.0
# Rhode Island         2021.0           4812.0
# South Carolina       2021.0          37880.0
# South Dakota         2021.0           3923.0
# Tennessee            2021.0          54582.0
# Texas                2021.0         194842.0
# Utah                 2021.0          10636.0
# Vermont              2021.0           1225.0
# Virginia             2021.0          37860.0
# Washington           2021.0          24552.0
# West Virginia        2021.0          15446.0
# Wisconsin            2021.0          24231.0
# Wyoming              2021.0           3829.0

# %%
states_df = pd.read_csv("Resources/us-states.csv")
#ohio_df = pd.Series(states_df.values.flatten())
states_df["date"] = states_df["date"].astype(str).str.slice(stop=4)
ohio_df = states_df.loc[(states_df["date"] == "2021"), :]
ohio_df = ohio_df.groupby(["state", "date"])["cases", "deaths"].sum()
#str.slice(stop=2)
ohio_df.head()
# Out:
# /var/folders/2m/3btzbqcn15d143__kkvb77f80000gn/T/ipykernel_47033/2269006493.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ohio_df = ohio_df.groupby(["state", "date"])["cases", "deaths"].sum()
#                          cases   deaths
# state          date
# Alabama        2021  227783813  4330518
# Alaska         2021   31953929   163285
# American Samoa 2021        563        0
# Arizona        2021  350481384  6590800
# Arkansas       2021  144787513  2367660

# %%
connection_string = "postgres:postgres@localhost:5432/covid_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# /var/folders/2m/3btzbqcn15d143__kkvb77f80000gn/T/ipykernel_47033/4162273999.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['covidcases', 'coviddeaths']

# %%
all_states_df.to_sql(name='coviddeaths', con=engine, if_exists='append', index=True)
ohio_df.to_sql(name='covidcases', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     961             xtras = self._psycopg2_extras()
# --> 962             context._psycopg2_fetched_rows = xtras.execute_values(
#     963                 cursor,
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/psycopg2/extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1291         parts[-1:] = post
# -> 1292         cur.execute(b''.join(parts))
#    1293         if fetch:
#
# UndefinedColumn: column "State" of relation "coviddeaths" does not exist
# LINE 1: INSERT INTO coviddeaths ("State", "Year", "COVID-19 Deaths")...
#                                  ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# /var/folders/2m/3btzbqcn15d143__kkvb77f80000gn/T/ipykernel_47033/1047253289.py in <module>
# ----> 1 all_states_df.to_sql(name='coviddeaths', con=engine, if_exists='append', index=True)
#       2 ohio_df.to_sql(name='covidcases', con=engine, if_exists='append', index=True)
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1759         )
#    1760
# -> 1761         sql_engine.insert_records(
#    1762             table=table,
#    1763             con=self.connectable,
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1261             )
#    1262         else:
# -> 1263             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1264
#    1265     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321     ):
#     322         if _force or self.supports_execution:
# --> 323             return connection._execute_clauseelement(
#     324                 self, multiparams, params, execution_options
#     325             )
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1450             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1451         )
# -> 1452         ret = self._execute_context(
#    1453             dialect,
#    1454             dialect.execution_ctx_cls._init_compiled,
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1812
#    1813         except BaseException as e:
# -> 1814             self._handle_dbapi_exception(
#    1815                 e, statement, parameters, cursor, context
#    1816             )
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1993                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1994             elif should_wrap:
# -> 1995                 util.raise_(
#    1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1749                             break
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#    1753                     )
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     960                 kwargs = {}
#     961             xtras = self._psycopg2_extras()
# --> 962             context._psycopg2_fetched_rows = xtras.execute_values(
#     963                 cursor,
#     964                 statement,
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/psycopg2/extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1290             parts.append(b',')
#    1291         parts[-1:] = post
# -> 1292         cur.execute(b''.join(parts))
#    1293         if fetch:
#    1294             result.extend(cur.fetchall())
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "State" of relation "coviddeaths" does not exist
# LINE 1: INSERT INTO coviddeaths ("State", "Year", "COVID-19 Deaths")...
#                                  ^
#
# [SQL: INSERT INTO coviddeaths ("State", "Year", "COVID-19 Deaths") VALUES (%(State)s, %(Year)s, %(COVID-19 Deaths)s)]
# [parameters: ({'State': 'Alabama', 'Year': 2021.0, 'COVID-19 Deaths': 38808.0}, {'State': 'Alaska', 'Year': 2021.0, 'COVID-19 Deaths': 3320.0}, {'State': 'Arizona', 'Year': 2021.0, 'COVID-19 Deaths': 56120.0}, {'State': 'Arkansas', 'Year': 2021.0, 'COVID-19 Deaths': 21302.0}, {'State': 'California', 'Year': 2021.0, 'COVID-19 Deaths': 192778.0})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
